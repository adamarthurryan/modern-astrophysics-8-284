# %%
import numpy as np
import matplotlib.pyplot as plt 
from scipy.integrate import solve_ivp

def f(y,t):
    return -0.5 * y

a,b=0,10
t=np.arange(a,b,np.abs(a-b)/1000.0)
y0=2


sol = solve_ivp(f,[a,b], [y0], t_eval=t)

plt.plot(sol.t, sol.y[0])
plt.xlim(a,b)
plt.show()
