# %%
import numpy as np
import matplotlib.pyplot as plt 
from scipy import integrate

#integrate from 0 to pi/2 of sin^4(x) dx

def sin4 (x):
    return np.sin(x)**4

def plotquad(f, a, b):
    x = np.arange(a, b, np.abs(a-b)/100.0)
    y = f(x)
    plt.plot(x,y)
    plt.show() 

    return integrate.quad(f, a, b)

res, err = plotquad(f, 0, np.pi/2)

print("The numerical result is {:f} (+-{:g})"
    .format(res, err))
# Out:
# The numerical result is 0.589049 (+-6.53975e-15)
